# %%
import os
import shutil
from bs4 import BeautifulSoup
import zipfile

def prettify_html_file(input_file_path, output_folder):
    try:
        with open(input_file_path, 'r', encoding='utf-8') as file:
            html_code = file.read()
        soup = BeautifulSoup(html_code, 'html.parser')
        prettified_html = soup.prettify()

        output_file_path = os.path.join(output_folder, os.path.basename(input_file_path))

        with open(output_file_path, 'w', encoding='utf-8') as file:
            file.write(prettified_html)

        print(f'Prettified and saved: {output_file_path}')
    except Exception as e:
        print(f'Error processing {input_file_path}: {str(e)}')

input_folder = './'

output_folder = './prettified_html/'

if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for filename in os.listdir(input_folder):
    if filename.endswith('.html'):
        input_file_path = os.path.join(input_folder, filename)
        prettify_html_file(input_file_path, output_folder)

shutil.make_archive(output_folder, 'zip', output_folder)

zip_file_path = f'{output_folder}.zip'

print(f'ZIP archive created: {zip_file_path}')
# Out:
# Prettified and saved: ./prettified_html/sweetalerts.html
# Prettified and saved: ./prettified_html/customerreport.html
# Prettified and saved: ./prettified_html/chart-morris.html
# Prettified and saved: ./prettified_html/form-mask.html
# Prettified and saved: ./prettified_html/email.html
# Prettified and saved: ./prettified_html/subaddcategory.html
# Prettified and saved: ./prettified_html/addpurchase.html
# Prettified and saved: ./prettified_html/icon-ionic.html
# Prettified and saved: ./prettified_html/rangeslider.html
# Prettified and saved: ./prettified_html/supplierlist.html
# Prettified and saved: ./prettified_html/chart-peity.html
# Prettified and saved: ./prettified_html/calendar.html
# Prettified and saved: ./prettified_html/editexpense.html
# Prettified and saved: ./prettified_html/customerlist.html
# Prettified and saved: ./prettified_html/adduser.html
# Prettified and saved: ./prettified_html/counter.html
# Prettified and saved: ./prettified_html/addsupplier.html
# ...

# %%
import os
from bs4 import BeautifulSoup
import zipfile

# Function to prettify an HTML file
def prettify_html_file(input_file_path, output_folder):
    try:
        # Read the HTML file
        with open(input_file_path, 'r', encoding='utf-8') as file:
            html_code = file.read()

        # Parse the HTML code
        soup = BeautifulSoup(html_code, 'html.parser')
        prettified_html = soup.prettify()

        # Determine the output file path
        output_file_path = os.path.join(output_folder, os.path.basename(input_file_path))

        # Write the prettified HTML to the output file
        with open(output_file_path, 'w', encoding='utf-8') as file:
            file.write(prettified_html)

        print(f'Prettified and saved: {output_file_path}')
    except Exception as e:
        print(f'Error processing {input_file_path}: {str(e)}')

# Specify the directory containing the HTML files
input_folder = './'

# Specify the folder where prettified files will be saved
output_folder = './prettified_html/'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Iterate through HTML files in the folder and prettify them
for filename in os.listdir(input_folder):
    if filename.endswith('.html'):
        input_file_path = os.path.join(input_folder, filename)
        prettify_html_file(input_file_path, output_folder)

# Create a ZIP archive of the prettified HTML files
with zipfile.ZipFile('prettified_html.zip', 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(output_folder):
        for file in files:
            file_path = os.path.join(root, file)
            arcname = os.path.relpath(file_path, output_folder)
            zipf.write(file_path, arcname)

print('ZIP archive created: prettified_html.zip')
# Out:
# Prettified and saved: ./prettified_html/sweetalerts.html
# Prettified and saved: ./prettified_html/customerreport.html
# Prettified and saved: ./prettified_html/chart-morris.html
# Prettified and saved: ./prettified_html/form-mask.html
# Prettified and saved: ./prettified_html/email.html
# Prettified and saved: ./prettified_html/subaddcategory.html
# Prettified and saved: ./prettified_html/addpurchase.html
# Prettified and saved: ./prettified_html/icon-ionic.html
# Prettified and saved: ./prettified_html/rangeslider.html
# Prettified and saved: ./prettified_html/supplierlist.html
# Prettified and saved: ./prettified_html/chart-peity.html
# Prettified and saved: ./prettified_html/calendar.html
# Prettified and saved: ./prettified_html/editexpense.html
# Prettified and saved: ./prettified_html/customerlist.html
# Prettified and saved: ./prettified_html/adduser.html
# Prettified and saved: ./prettified_html/counter.html
# Prettified and saved: ./prettified_html/addsupplier.html
# ...
